# %% [markdown]
# # Unit 10. 데이터 시각화

# %% [markdown]
# ## 1. matplotlib

# %% [markdown]
# - MATLAB 인터페이스와 유사한 데이터 시각화 도구
# - pip install matplotlib
# - https://matplotlib.org
# - https://matplotlib.org/gallery.html

# %% [markdown]
# ### 1) 그림의 구조

# %% [markdown]
# matplotlib가 그리는 그림은 Figure 객체, Axes 객체, Axis 객체 등으로 구성된다.
# Figure 객체는 한 개 이상의  Axes 객체를 포함하고 Axes 객체는 다시 두 개 이상의 Axis 객체를 포함한다.
# 다음 그림은 이 구조를 설명하고 있다.
#
# <img src="https://datascienceschool.net/upfiles/4e20efe6352e4f4fac65c26cb660f522.png" style="width: 50%">
#
# Figure는 그림이 그려지는 캔버스나 종이를 뜻하고 Axes는 하나의 플롯, 그리고 Axis는 가로축이나 세로축 등의 축을 뜻한다.

# %% [markdown]
# ### 2) 선 그래프(line plot)

# %%
import matplotlib.pyplot as plt

# %%
plt.plot([3, 4, 5, 6, 7, 8],[13, 16, 21, 25, 29, 33], 'ro-') #x축 값, y축 값 지정하고 선 그래프 그리기
plt.show() #그래프 보여주기

# %%
plt.rc('font', family = 'Malgun Gothic') #폰트 지정
plt.figure(dpi=150)
# 색 r g b k y
#마커(데이터 위치를 나타내는 기호) . , ^ s o + *
#선 - -- -.
plt.plot([3, 4, 5, 6, 7, 8],[13, 16, 21, 25, 29, 33], 'ks--') #x축 값, y축 값 지정하고 선 그래프 그리기
plt.axis([2.5, 8.5, 10, 40])
plt.xlabel('월')
plt.ylabel('온도')
plt.title('월별 평균 온도')
plt.show() #그래프 보여주기

# %%
import matplotlib.pyplot as plt
x = range(0, 100)
y = [v*v for v in x]
plt.plot(x, y)
plt.show()

# %%
# y=x, y=x**2, y=x**3
import matplotlib.pyplot as plt
import numpy as np
x_range = np.arange(0, 5, 0.2)
plt.rc('font', family = 'Malgun Gothic')
plt.figure(figsize = (5, 3), dpi=150)
plt.plot(x_range, x_range, label = 'y=x')
plt.plot(x_range, x_range**2, label = 'y=x**2')
plt.plot(x_range, x_range**3, label = 'y=y**3')
plt.legend(loc = 'upper right') #upper lower right left center
plt.axis([-0.5, 5.5, -0.5, 5.5])
plt.xlabel('x축')
plt.ylabel('y축')
plt.title('여러 종류 그래프')
plt.savefig('여러종류그래프.png')
plt.show()
